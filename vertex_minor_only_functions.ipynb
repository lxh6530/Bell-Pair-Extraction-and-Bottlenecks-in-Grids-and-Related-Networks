# %%
import scipy
import networkx as nx #A python library that seems helpful when dealing with graphs 
import matplotlib.pyplot as plt

##fix the issues with the columns
